# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '3.0.5'

# %%
df=pd.read_csv("car_fuel_efficiency_2026.csv")

# %%
len(df)
# Out:
# 10000

# %%
df
# Out:
#       model_year  origin fuel_type         drivetrain  num_doors  \
# 0           2006  Europe  Gasoline  Front-wheel drive          4
# 1           2008  Europe    Diesel  Front-wheel drive          4
# 2           1996    Asia  Gasoline  Front-wheel drive          5
# 3           1989  Europe  Gasoline  Front-wheel drive          4
# 4           1994     USA    Diesel  Front-wheel drive          3
# ...          ...     ...       ...                ...        ...
# 9995        2005     USA  Gasoline    All-wheel drive          4
# 9996        1993    Asia  Gasoline    All-wheel drive          2
# 9997        2014     USA  Gasoline    All-wheel drive          3
# 9998        2004     USA    Hybrid   Rear-wheel drive          5
# 9999        2011     USA    Diesel  Front-wheel drive          4
#
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                    2180              6       243.0            3870
# 1                    2390              6       272.0            4210
# 2                    2320              6       267.0            4240
# 3                    2130              6       258.0            4490
# 4                    2580              7       304.0            4510
# ...                   ...            ...         ...             ...
# 9995                 2470              6       271.0            4690
# 9996                 2300              6       244.0            4370
# 9997                 2480              6       267.0            4590
# 9998                 2180              6       270.0            4450
# 9999                 2380              6       295.0            4370
#
#       acceleration  fuel_efficiency_mpg
# 0              NaN                 31.9
# 1              NaN                 31.3
# 2             17.3                 27.5
# 3             18.7                 28.5
# 4             17.5                 31.0
# ...            ...                  ...
# 9995          18.9                 27.4
# 9996          19.0                 30.0
# 9997          18.4                 28.1
# 9998          20.9                 32.2
# 9999          17.6                 30.2
#
# [10000 rows x 11 columns]

# %%
df["fuel_type"].nunique()
# Out:
# 3

# %%
df.isnull().any().sum()
# Out:
# np.int64(2)

# %%
df[df["origin"] == "Asia"]["fuel_efficiency_mpg"].max()
# Out:
# np.float64(41.2)

# %%
median_b = df["horsepower"].median()

mode_hp = df["horsepower"].mode()[0]

median_af = df["horsepower"].fillna(mode_hp).median()

median_b, mode_hp, median_af
# Out:
# (np.float64(254.0), np.float64(252.0), np.float64(252.0))

# %%
df_asia = df[df["origin"] == "Asia"]

X = df_asia[["vehicle_weight", "model_year"]].head(7).values

XTX = X.T.dot(X)
XTX_inv = np.linalg.inv(XTX)

y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

w = XTX_inv.dot(X.T).dot(y)

w.sum()
# Out:
# np.float64(0.36919696904925486)
